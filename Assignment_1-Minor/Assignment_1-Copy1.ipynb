# %% [markdown]
# <div style="font-size:18pt; padding-top:20px; text-align:center">ЗАДАНИЕ 1. <b>Дескриптивный анализ данных и </b> <span style="font-weight:bold; color:green">Pandas/Matplotlib</span></div><hr>
# <div style="text-align:right;">Папулин С.Ю. <span style="font-style: italic;font-weight: bold;">(papulin_hse@mail.ru)</span></div>

# %% [markdown]
# <a name="0"></a>
# <div><span style="font-size:14pt; font-weight:bold">Содержание</span>
#     <ol>
#         <li><a href="#1">Варианты</a></li>
#         <li><a href="#2">Задание</a></li>
#     </ol>
# </div>

# %% [markdown]
# <p>Подключение стилей оформления</p>

# %%
# %%html
# <link href="css/style.css" rel="stylesheet" type="text/css">
# Out:
# <link href="css/style.css" rel="stylesheet" type="text/css">

# %% [markdown]
# <a name="1"></a>
# <div style="display:table; width:100%; padding-top:10px; padding-bottom:10px; border-bottom:1px solid lightgrey">
#     <div style="display:table-row">
#         <div style="display:table-cell; width:80%; font-size:14pt; font-weight:bold">1. Варианты</div>
#     	<div style="display:table-cell; width:20%; text-align:center; background-color:whitesmoke; border:1px solid lightgrey"><a href="#0">К содержанию</a></div>
#     </div>
# </div>

# %% [markdown]
# <p>Чтобы узнать свой вариант, введите Вашу фамилию в соответвующее поле ниже и запустите ячейку:</p>

# %%
surname = "Арбузов" #Ваша фамилия

alp = 'абвгдеёжзийклмнопрстуфхцчшщъыьэюя'
w = [1, 42, 21, 21, 34,  6, 44, 26, 18, 44, 38, 26, 14, 43,  4, 49, 45,
        7, 42, 29,  4,  9, 36, 34, 31, 29,  5, 30,  4, 19, 28, 25, 33]

d = dict(zip(alp, w))
variant =  sum([d[el] for el in surname.lower()]) % 40 + 1

print("Задача № 1, шаг 5 - вариант: ", variant % 5 + 1)
print("Задача № 1, шаг 11 - вариант: ", variant % 2 + 1 )
print("задача № 2 - вариант: ", variant % 4 + 1)
# Out:
# Задача № 1, шаг 5 - вариант:  4
# Задача № 1, шаг 11 - вариант:  2
# задача № 2 - вариант:  4

# %% [markdown]
# <div class="msg-block msg-warning">
#   <p class="msg-text-warn">Варианты могут не совпадать с последующими ДЗ</p>
# </div>

# %% [markdown]
# <a name="2"></a>
# <div style="display:table; width:100%; padding-top:10px; padding-bottom:10px; border-bottom:1px solid lightgrey">
#     <div style="display:table-row">
#         <div style="display:table-cell; width:80%; font-size:14pt; font-weight:bold">2. Задание</div>
#     	<div style="display:table-cell; width:20%; text-align:center; background-color:whitesmoke; border:1px solid lightgrey"><a href="#0">К содержанию</a></div>
#     </div>
# </div>

# %% [markdown]
# <div class="msg-block msg-imp">
#   <div class="msg-text-imp">
#       <p>СРОК СДАЧИ: до <b>09 марта 2017</b></p>
#       <p style="margin:0px">ПОСЛЕ СРОКА: первая неделя <b>-25%</b>, вторая неделя и далее до конца модуля <b>-50%</b>, потом <b>0 баллов</b>
#       </p>
#   </div>
# </div>

# %% [markdown]
# <p><b>Задача 1.</b> Анализ индекса восприятия коррупции (Corruption Perceptions Index, CPI)</p>

# %% [markdown]
# <p>1. Подключите библиотеки numpy, pandas, matplotlib</p>

# %%
# будем отображать графики прямо в jupyter'e
# %pylab inline

#Ваш код
import numpy as np
import pandas as pd
import matplotlib as mlt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# <p>2. Загрузите данные из "data/Corruption_Perception_Index.csv" в DataFrame. Исходные данные и пояснения можно найти <a href="http://www.transparency.org/news/feature/corruption_perceptions_index_2016#table">здесь</a></p>

# %%
#Ваш код

data = pd.read_csv('data/Corruption_Perception_Index.csv')
data.head()
# Out:
#    2016 Rank      Country  2016 Score  2015 Score  2014 Score  2013 Score  \
# 0          1      Denmark          90        91.0        92.0        91.0
# 1          1  New Zealand          90        88.0        91.0        91.0
# 2          3      Finland          89        90.0        89.0        89.0
# 3          4       Sweden          88        89.0        87.0        89.0
# 4          5  Switzerland          86        86.0        86.0        85.0
#
#    2012 Score                   Region
# 0        90.0  Europe and Central Asia
# 1        90.0             Asia Pacific
# 2        90.0  Europe and Central Asia
# 3        88.0  Europe and Central Asia
# 4        86.0  Europe and Central Asia

# %% [markdown]
# <p>3. Отсортируйте данные по убыванию индекса DataFrame</p>

# %%
#Ваш код

sortedData = data.sort_index(ascending=False)
sortedData.head()
# Out:
#      2016 Rank        Country  2016 Score  2015 Score  2014 Score  2013 Score  \
# 175        176        Somalia          10         8.0         8.0         8.0
# 174        175    South Sudan          11        15.0        15.0        14.0
# 173        174  Korea (North)          12         8.0         8.0         8.0
# 172        173          Syria          13        18.0        20.0        17.0
# 171        170          Yemen          14        18.0        19.0        18.0
#
#      2012 Score                        Region
# 175         8.0            Sub Saharan Africa
# 174         NaN            Sub Saharan Africa
# 173         8.0                  Asia Pacific
# 172        26.0  Middle East and North Africa
# 171        23.0  Middle East and North Africa

# %% [markdown]
# <div><p>4. Отобразите данные по индексу CPI за 2016 год в виде горизонтального столбчатого графика. Примерный вид графика приведен ниже</p>
# <img src="img/cpi_2016_.png"></div>

# %%
#Ваш код



plt.figure("15", figsize=[4,30])
subpl = plt.subplot(1, 1, 1)

plt.barh(sorted_df["Country"].index + 1, sorted_df["2016 Score"], 0.5, color = 'green')
subpl.set_yticks((sorted_df["Country"].index+1) + 0.5 / 2)

subpl.set_yticklabels(sorted_df["Country"], rotation='horizontal')
plt.ylim([1, 177])

subpl.invert_yaxis()
subpl.get_xaxis().tick_top()

plt.grid(axis = '-', color ='black', linestyle='-')
plt.grid(True)
plt.show()

# %% [markdown]
# <p>5. Сформируйте DataFrame из исходного для региона в соответствии с Вашим вариантом</p>
# <p><b>Вариант 1.</b> Asia Pacific</p>
# <p><b>Вариант 2.</b> Americas</p>
# <p><b>Вариант 3.</b> Europe and Central Asia</p>
# <p><b>Вариант 4.</b> Middle East and North Africa</p>
# <p><b>Вариант 5.</b> Sub Saharan Africa</p>

# %%
#Ваш код
MENZData = data[data['Region'] == 'Middle East and North Africa']
# Out:
#     2016 Rank               Country  2016 Score  2015 Score  2014 Score  \
# 25         24  United Arab Emirates          66        70.0        70.0
# 27         28                Israel          64        61.0        60.0
# 31         31                 Qatar          61        71.0        69.0
# 57         57                Jordan          48        53.0        49.0
# 62         62          Saudi Arabia          46        52.0        49.0
#
#     2013 Score  2012 Score                        Region
# 25        69.0        68.0  Middle East and North Africa
# 27        61.0        60.0  Middle East and North Africa
# 31        68.0        68.0  Middle East and North Africa
# 57        45.0        48.0  Middle East and North Africa
# 62        46.0        44.0  Middle East and North Africa

# %% [markdown]
# <p>6. Выведите данные DataFrame'a</p>

# %%
#Ваш код

MENZData
# Out:
#      2016 Rank               Country  2016 Score  2015 Score  2014 Score  \
# 25          24  United Arab Emirates          66        70.0        70.0
# 27          28                Israel          64        61.0        60.0
# 31          31                 Qatar          61        71.0        69.0
# 57          57                Jordan          48        53.0        49.0
# 62          62          Saudi Arabia          46        52.0        49.0
# 64          64                  Oman          45        45.0        45.0
# 69          70               Bahrain          43        51.0        49.0
# 75          75                Kuwait          41        49.0        44.0
# 76          75               Tunisia          41        38.0        40.0
# 92          90               Morocco          37        36.0        39.0
# 107        108               Algeria          34        36.0        36.0
# 109        108                 Egypt          34        36.0        37.0
# ...

# %% [markdown]
# <div><p>7. Постройте графики индекса CPI за 2012-2016 для стран своего региона. Примерный вид графика приведен ниже</p>
# <img src="img/fig_springfield_region.png">
# </div>

# %%
#Ваш код

plot = pd.concat([MENZData['2012 Score'], MENZData['2013 Score'], MENZData['2014 Score'], MENZData['2015 Score'], MENZData['2016 Score']], axis=1, keys=['2012 Score', '2013 Score', '2014 Score','2015 Score','2016 Score'])
plot.index = range(1, 21)

plt.figure(figsize=(10,6))
plt.title('Springfield')
plt.ylabel('CPI')
plt.yticks(range(20, 81, 10))
plt.xticks(np.arange(5), ('2016 Score', '2015 Score', '2014 Score', '2013 Score', '2012 Score'))
plt.grid(axis='both', which='major')

for x in plot.values:
    plt.plot(x, color='lightgrey', linewidth=1.5, marker='o', markerfacecolor='lightgrey', markersize=5)

plt.show()

# %% [markdown]
# <p>8. Найдите страны с наибольшим и наименьшим значением CPI Вашего варианта региона за 2016 год</p>

# %%
#Ваш код
MENZData[MENZData['2016 Score'] == MENZData['2016 Score'].max()]['Country']
# Out:
# 25    United Arab Emirates
# Name: Country, dtype: object

# %%
MENZData[MENZData['2016 Score'] == MENZData['2016 Score'].min()]['Country']
# Out:
# 172    Syria
# Name: Country, dtype: object

# %% [markdown]
# <p>9. Определите средние значения за каждый год в период с 2012 по 2016</p>

# %%
#Ваш код

MENZData.mean()
# Out:
# 2016 Rank     102.50
# 2016 Score     35.80
# 2015 Score     38.20
# 2014 Score     37.75
# 2013 Score     36.65
# 2012 Score     38.20
# dtype: float64

# %% [markdown]
# <div><p>10. Постройте графики индекса CPI за 2012-2016 для стран своего региона и выделите страны с наибольшим и наименьшим значением CPI за 2016 год, а также постройте графики для средних значение по региону и РФ. Примерный вид графика приведен ниже</p>
# <img src="img/fig_springfield_region_comb.png">
# </div>

# %%
#Ваш код


plot = pd.concat([MENZData['2012 Score'], MENZData['2013 Score'], MENZData['2014 Score'], MENZData['2015 Score'], MENZData['2016 Score']], axis=1, keys=['2012 Score', '2013 Score', '2014 Score','2015 Score','2016 Score'])
plot.index = range(1, 21)

dataRussia = data[data['Country'] == 'Russia']
plotRussia = pd.concat([dataRussia['2012 Score'], dataRussia['2013 Score'], dataRussia['2014 Score'], dataRussia['2015 Score'], dataRussia['2016 Score']], axis=1, keys=['2012 Score', '2013 Score', '2014 Score','2015 Score','2016 Score'])
plotRussia.index = range(1, )

dataMax = MENZData[MENZData['2016 Score'] == MENZData['2016 Score'].max()]
plotMax = pd.concat([dataMax['2012 Score'], dataMax['2013 Score'], dataMax['2014 Score'], dataMax['2015 Score'], dataMax['2016 Score']], axis=1, keys=['2012 Score', '2013 Score', '2014 Score','2015 Score','2016 Score'])
plotMax.index = range(1, )

dataMin = MENZData[MENZData['2016 Score'] == MENZData['2016 Score'].min()]
plotMin = pd.concat([dataMin['2012 Score'], dataMin['2013 Score'], dataMin['2014 Score'], dataMin['2015 Score'], dataMin['2016 Score']], axis=1, keys=['2012 Score', '2013 Score', '2014 Score','2015 Score','2016 Score'])
plotMin.index = range(1, )



plt.figure(figsize=(10,6))
plt.title('Springfield')
plt.ylabel('CPI')
plt.yticks(range(20, 81, 10))
plt.xticks(np.arange(5), ('2016 Score', '2015 Score', '2014 Score', '2013 Score', '2012 Score'))
plt.grid(axis='both', which='major')



for x in plot.values:
    plt.plot(x, color='lightgrey', linewidth=1.5, marker='o', markerfacecolor='lightgrey', markersize=5)

for x in plotRussia.values:
    plt.plot(x, color='yellow', linewidth=3, marker='o', markerfacecolor='yellow', markersize=5, label = 'Russia')
    
for x in plotMax.values:
    plt.plot(x, color='red', linewidth=3, marker='o', markerfacecolor='red', markersize=5, label = 'max')
    
for x in plotMin.values:
    plt.plot(x, color='green', linewidth=3, marker='o', markerfacecolor='green', markersize=5, label = 'min')
    
for x in [[MENZData['2012 Score'].mean(),  MENZData['2013 Score'].mean(), MENZData['2014 Score'].mean(),  MENZData['2015 Score'].mean(),  MENZData['2016 Score'].mean() ]]:
    plt.plot(x, color='blue', linewidth=4, marker='o', markerfacecolor='blue', markersize=5, label = 'mean')
    
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)   
plt.show()

# %% [markdown]
# <p>11. Определите как изменилось значение показателя в соответсвии с Вашим вариантом с 2012 по 2016</p>
# <p><b>Вариант 1.</b> На сколько позиций в рейтинге c 2012 по 2016</p>
# <p><b>Вариант 2.</b> На сколько процентов значение CPI с 2012 по 2016</p>

# %%
# вариант 2
def proc(newVal, oldVal):
    return '{:.2%}'.format((newVal - oldVal)/oldVal)


data['changes'] = [proc(data['2016 Score'][i], data['2012 Score'][i]) for i in data.index]
data.head()
# Out:
# 90
#    2016 Rank      Country  2016 Score  2015 Score  2014 Score  2013 Score  \
# 0          1      Denmark          90        91.0        92.0        91.0
# 1          1  New Zealand          90        88.0        91.0        91.0
# 2          3      Finland          89        90.0        89.0        89.0
# 3          4       Sweden          88        89.0        87.0        89.0
# 4          5  Switzerland          86        86.0        86.0        85.0
#
#    2012 Score                   Region changes
# 0        90.0  Europe and Central Asia   0.00%
# 1        90.0             Asia Pacific   0.00%
# 2        90.0  Europe and Central Asia  -1.11%
# 3        88.0  Europe and Central Asia   0.00%
# 4        86.0  Europe and Central Asia   0.00%

# %% [markdown]
# <div class="msg-block msg-info">
#   <p class="msg-text-info">У нескольких стран может быть одна и та же позиция в рейтинге из-за одинаковых значений индекса</p>
# </div>

# %% [markdown]
# <p>12. Выведите </p>

# %%
import pandas as pnd

index = ["mean_2016", "max_2016", "min_2016", "Russia_2016"]
columns = ["Region", "Country", "Score 2012", "Score 2016", "Change in Position"]

# %%
columns = ["Region", "Country", "Score 2012", "Score 2016", "Change in Position"]
df = pnd.DataFrame(index=index, columns=columns)
df

# %%
columns = ["Region", "Country", "2012 Score", "2016 Score", "changes"]
df = data[columns]
df.head()
# Out:
#                     Region      Country  2012 Score  2016 Score changes
# 0  Europe and Central Asia      Denmark        90.0          90   0.00%
# 1             Asia Pacific  New Zealand        90.0          90   0.00%
# 2  Europe and Central Asia      Finland        90.0          89  -1.11%
# 3  Europe and Central Asia       Sweden        88.0          88   0.00%
# 4  Europe and Central Asia  Switzerland        86.0          86   0.00%

# %%
#Ваш код

# %% [markdown]
# <p><b>Задача 2.</b> Анализ рынка акций</p>

# %% [markdown]
# <p>1. Загрузите данные в один dataframe из всех файлов в папке /data/stock. Все файлы имеют одинаковую структуру, в том числе наименование столбцов. В качестве значений индекса dataframe'а необходимо указать значения столбца "Date". Название столбцов должные соответствовать названию акций (имя файла без .csv), а их значения - значениям цены закрытия (столбец "Close" в файлах .csv)</p>

# %%
#Ваш код
# import os
# os.listdir(file_path) - список файлов в папке file_path
# pnd.read_csv(full_file_name, index_col=0, parse_dates=True) - загрузка из файла в dataframe
# dfStock["Close"] - нужна только цена закрытия



import os
directory = "data/stock/"

flist = os.listdir(directory)
res = pd.DataFrame()
 
for file in flist:

    first = pd.read_csv(directory + file, index_col=0, parse_dates=True)
    res[file[:-4]] = first['Close']

res
# Out:
#                   INTU        VMW         CA        CRM        ADBE  \
# Date
# 2017-02-01  125.440002  89.889999  32.270000  81.349998  118.339996
# 2017-01-03  118.580002  87.540001  31.270000  79.099998  113.379997
# 2016-12-01  114.610001  78.730003  31.770000  68.459999  102.949997
# 2016-11-01  113.680000  81.139999  31.959999  72.000000  102.809998
# 2016-10-03  108.739998  78.599998  30.740000  75.160004  107.510002
# 2016-09-01  110.010002  73.349998  33.080002  71.330002  108.540001
# 2016-08-01  111.449997  73.330002  33.910000  79.419998  102.309998
# 2016-07-01  110.989998  72.980003  34.650002  81.800003   97.860001
# 2016-06-01  111.610001  57.220001  32.830002  79.410004   95.790001
# 2016-05-02  106.660004  60.560001  32.320000  83.709999   99.470001
# 2016-04-01  100.889999  56.910000  29.660000  75.800003   94.220001
# 2016-03-01  104.010002  52.310001  30.790001  73.830002   93.800003
# 2016-02-01   96.639999  50.490002  29.290001  67.750000   85.150002
# ...

# %% [markdown]
# <p>2. Рассчитайте корреляционную матрицу для всех акций</p>

# %%
#Ваш код

corr = res.corr()
corr
# Out:
#            INTU       VMW        CA       CRM      ADBE      ADSK      PYPL  \
# INTU   1.000000  0.323059  0.718292  0.492148  0.805904  0.832712  0.750377
# VMW    0.323059  1.000000  0.216074 -0.103050  0.007322  0.317948  0.289105
# CA     0.718292  0.216074  1.000000  0.335133  0.470015  0.527015  0.563574
# CRM    0.492148 -0.103050  0.335133  1.000000  0.534918  0.387552  0.148632
# ADBE   0.805904  0.007322  0.470015  0.534918  1.000000  0.853387  0.815057
# ADSK   0.832712  0.317948  0.527015  0.387552  0.853387  1.000000  0.798648
# PYPL   0.750377  0.289105  0.563574  0.148632  0.815057  0.798648  1.000000
# TWTR  -0.439487  0.462485 -0.177609 -0.437294 -0.744648 -0.374832 -0.609176
# NVDA   0.833649  0.271619  0.517295  0.286524  0.887010  0.892613  0.708027
# RHT    0.306462  0.292572  0.065133  0.493769  0.295120  0.422972  0.260888
# BABA   0.800199  0.411332  0.594163  0.387174  0.714708  0.873751  0.783197
# ...

# %% [markdown]
# <p>3. Отобразите корреляционную матрицив в виде диаграммы. Примерный вид графика приведен ниже</p>
# <img src="img/fig_corr_matrix.png" width="400px">

# %%
#Ваш код
# matshow(corrMatrix, vmin=-1, vmax=1)

plt.figure(figsize=(24,24))


plt.matshow(corr, vmin=-1, vmax=1, aspect='auto')

plt.title('Correlation matrix diagram\n')

plt.colorbar()
plt.yticks(np.arange(23), corr.columns.values, rotation = 0)
plt.xticks(np.arange(23), corr.columns.values, rotation = 90)


plt.show()

# %% [markdown]
# <div>
# <p>4. В соответствии с Вашим вариантом определите:</p>
# <ul>
#     <li>акцию с максимальной корреляцией (max)</li>
#     <li>акцию с минимальной корреляцией (min) </li>
#     <li>акцию, которая больше всего соответствует отсутствию какой-либо корреляции (none)</li>
# </ul>
# </div>

# %% [markdown]
# <p><b>Вариант 1.</b> Microsoft (MSFT)</p>
# <p><b>Вариант 2.</b> Facebook (FB)</p>
# <p><b>Вариант 3.</b> Google (GOOGL)</p>
# <p><b>Вариант 4.</b> Alibaba (BABA)</p>

# %%
#Ваш код
# вариант 4
maxS = -2
minS = 2
meanS = 0
meanSRes = 0
print(corr['BABA'])
for i in corr['BABA']:

    if(i > maxS and i != 1): maxS = i
    if(i < minS): minS = i
    if(1 - abs(i) > meanS): 
        meanSRes = i
        meanS = 1 - abs(i)
        
print(maxS)
print(minS)
print(meanSRes)
# Out:
# INTU     0.800199
# VMW      0.411332
# CA       0.594163
# CRM      0.387174
# ADBE     0.714708
# ADSK     0.873751
# PYPL     0.783197
# TWTR    -0.139319
# NVDA     0.699008
# RHT      0.556812
# BABA     1.000000
# INFY    -0.168569
# AKAM     0.087536
# FB       0.566607
# CTSH    -0.589198
# MSFT     0.661599
# SAP      0.805775
# YHOO     0.845418
# EBAY     0.198884
# NTES     0.806564
# BIDU     0.056031
# CHKP     0.429195
# GOOGL    0.452358
# Name: BABA, dtype: float64
# 0.873750903408
# -0.58919753305
# 0.0560311234802

# %% [markdown]
# <p>5. Постройте диаграммы разброса (Ваша компания - Компания с min), (Ваша компания - Компания с max), (Ваша компания - Компания с none)</p>

# %%
#Ваш код
# scatter

# CTSH ADSK BIDU 

print('BABA & CTSH')
plt.scatter(res['BABA'], res['CTSH'])
plt.show()

print('BABA & ADSK')
plt.scatter(res['BABA'], res['ADSK'])
plt.show()

print('BABA & BIDU')
plt.scatter(res['BABA'], res['BIDU'])
plt.show()
# Out:
# BABA & CTSH
# BABA & ADSK
# BABA & BIDU

# %% [markdown]
# <p>6. Рассчитайте среднюю цену акций для каждого месяца (исходные данные взяты с интервалом в месяц)</p>

# %%
res.fillna(0, inplace=True)

meanTab = {}

for i in range(24):
    time = pd.to_datetime(res.iloc[[i][0]].name, yearfirst = True)
    print('' + str(time.year) +' '+ str(time.month), end=' ')
     
    av = 0
    for i1 in range(res.iloc[[i][0]].size):
        #print(res.iloc[[i][0]][i1])
        if(res.iloc[[i][0]][i1] != NaN):
            av  = av + res.iloc[[i][0]][i1]
    print(av/res.iloc[[i][0]].size)
    meanTab['' + str(time.year) +'-'+ str(time.month)] = av/res.iloc[[i][0]].size
# Out:
# 2017 2 122.210869304
# 2017 1 117.401738957
# 2016 12 109.423043739
# 2016 11 109.284782435
# 2016 10 112.875652826
# 2016 9 111.394783435
# 2016 8 107.825216913
# 2016 7 105.233915043
# 2016 6 98.1565226957
# 2016 5 101.787824783
# 2016 4 96.4326094348
# 2016 3 91.2621754348
# 2016 2 84.9669552609
# 2016 1 87.6747813913
# 2015 12 93.0995656522
# 2015 11 92.9943471304
# 2015 10 90.1486964783
# 2015 9 80.2169565652
# 2015 8 80.801739913
# 2015 7 84.7426084348
# 2015 6 80.0847814348
# 2015 5 82.6895655217
# 2015 4 81.3604358261
# 2015 3 80.3752182174

# %% [markdown]
# <p>7. Постройте графики для акций из пункта 4 и средней из пункта 6. Примерный вид графика приведен ниже</p>
# <img src="img/fig_tw_comp.png">

# %%
#Ваш код
#BABA CTSH ADSK BIDU 

plt.figure(figsize=(10,6))
plt.title('Alibaba comparison')
plt.ylabel('Price')
plt.yticks(range(20, 141, 20))
plt.xticks(np.arange(27), ('2015-03','', '', '2015-06','', '', '2015-09','','', '2015-12','','', '2016-03','','', '2016-06','','', '2016-09','','', '2016-12','','', '2017-03','','',))
plt.grid(axis='both', which='major')

#CTSH
for x in [list(res['CTSH'].values)]:
    plt.plot(x, color='green', linewidth=1.5, marker='o', markerfacecolor='green', markersize=5, label = 'Ctsh-MIN')

  
#BIDU 

# We do not need 0 on the graph
BIDUval = [None if i == 0 else i for i in list(res['BIDU'].values)]

for x in [BIDUval]:
    plt.plot(x, color='red', linewidth=1.5, marker='o', markerfacecolor='red', markersize=5, label = 'Bidu-NONE')


#ADSK 

for x in [list(res['ADSK'].values)]:
    plt.plot(x, color='orange', linewidth=1.5, marker='o', markerfacecolor='orange', markersize=5, label = 'Adsk-MAX')

for x in [list(res['BABA'].values)]:
    plt.plot(x, color='blue', linewidth=1.5, marker='o', markerfacecolor='blue', markersize=5, label = 'Alibaba')

for x in [list(meanTab.values())]:
    plt.plot(x, color='gray', linewidth=1.5, marker='o', markerfacecolor='gray', markersize=5, label = 'Average')

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)   

plt.show()

# %% [markdown]
# <p><b>Задача 3.</b> Отправить тетрадь на адрес <b>papulin_hse@mail.ru</b></p>
